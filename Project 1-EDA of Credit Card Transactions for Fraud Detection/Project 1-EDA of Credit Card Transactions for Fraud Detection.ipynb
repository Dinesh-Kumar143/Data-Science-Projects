# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# #### **Question 1: How many rows and columns are in the dataset?**<br>
# **Answer: There are 284807 rows 31 columns.**

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# #### **Question 6: What are the minimum, maximum, mean, and median values for numerical columns like Amount?**<br>
# **Answer: The values are shown below.**

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# #### **Question 2: What are the column names and their data types?**<br>
# **Answer: columns names are given below**

# %%
columns = df.columns.tolist()
columns
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount',
#  'Class']

# %% [markdown]
# #### **Question 3: Are there any missing or null values in the dataset?**
# **Answer: No there are no missing or null values present in data.**

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
fraud = df[df['Class'] == 1]
safe = df[df['Class']== 0]

# %%
total_fraud = fraud.shape[0]
total_Legitimate = safe.shape[0]
total_Transaction = df.shape[0]

# %% [markdown]
# #### **Question 4: How many transactions are fraudulent, and how many are legitimate?**
# **Answer: The numbers are shown below:**

# %%
print("Total Fraud Transaction:", total_fraud)
print("Total Legitimate Transaction:", total_Legitimate)
print("Total Transaction:", total_Transaction)
# Out:
# Total Fraud Transaction: 492
# Total Legitimate Transaction: 284315
# Total Transaction: 284807

# %% [markdown]
# #### **Question 5: What percentage of transactions are fraudulent?**
# **Answer: Percentage of Fraud Transaction:  0.1727485630620034**

# %%
print("Percentage of Fraud Transaction: ",(total_fraud/total_Transaction)*100)
# Out:
# Percentage of Fraud Transaction:  0.1727485630620034

# %% [markdown]
# #### **Question 7: What is the maximum transaction amount in the dataset, and is it fraudulent?**
# **Answer: The maximum transaction amount is 25691.16 and the the maximum fraud amount is 2125.87 so, Maximum tansaction amount is not fraudulant.**

# %%
df['Amount'].max()
# Out:
# 25691.16

# %%
max_fraud_transaction = fraud['Amount'].max()
max_fraud_transaction
# Out:
# 2125.87

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %% [markdown]
# #### **Question 8: Can we create a bar chart showing the count of fraudulent vs. legitimate transactions?**
# **Answer: Yes we can create a bar chart showing the count of fraudulent vs. legitimate transactions but The number of  Fraud cases are very low because of that fraud amount is not visible but, we can create Pie chart for better understand and better visibility as shown below bar chart.**

# %%
plt.bar(['Legitimate', 'Fraud'], [total_Legitimate, total_fraud], color=['b', 'r'])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.figure(facecolor='black')
plt.pie([total_Legitimate, total_fraud], labels=['Legitimate', 'Fraud'], autopct='%1.3f%%', colors=['y', 'r'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2275dd9bad0>,
# ...
#  [Text(-1.09998380137016, 0.0059696501784341355, 'Legitimate'),
#   Text(1.0999838018177286, -0.005969567707642625, 'Fraud')],
#  [Text(-0.5999911643837235, 0.0032561728246004373, '99.827%'),
#   Text(0.5999911646278518, -0.0032561278405323405, '0.173%')])

# %% [markdown]
# #### **Question 9: What does the histogram of transaction amounts look like?**
# **Answer: The histogram of Transaction values shows the highy right skewed showing bars are leaning towards right where most transactions cluster near zero and few high-value transactions are leaning towards right forming tail.**

# %%
plt.hist(df['Amount'], bins=50, color='red')
# Out:
# (array([2.75992e+05, 6.01000e+03, 1.53900e+03, 6.27000e+02, 2.27000e+02,
#         1.44000e+02, 9.20000e+01, 6.90000e+01, 3.30000e+01, 2.20000e+01,
#         1.00000e+01, 1.10000e+01, 5.00000e+00, 5.00000e+00, 5.00000e+00,
#         5.00000e+00, 1.00000e+00, 2.00000e+00, 0.00000e+00, 2.00000e+00,
#         0.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 0.00000e+00,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 1.00000e+00, 0.00000e+00, 1.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([    0.    ,   513.8232,  1027.6464,  1541.4696,  2055.2928,
#          2569.116 ,  3082.9392,  3596.7624,  4110.5856,  4624.4088,
#          5138.232 ,  5652.0552,  6165.8784,  6679.7016,  7193.5248,
# ...

# %% [markdown]
# #### **Question 10: Can we use a heatmap to visualize the correlation between numerical features?**
# **Answer: Yes, we can visualize the correlation between numerical features with heat map where the chart uses color intensity to represent the strength and direction of correlations with digonal showing perfect self-correlation with value 1.**

# %%
plt.figure(figsize=(8,6))
plt.imshow(df.corr(), cmap='hot', interpolation='nearest')
